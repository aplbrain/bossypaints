# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

import glob

path = "./exports"

images = list(sorted(glob.glob(path + "/*.tif")))

# %%
vol = np.stack([io.imread(image) for image in images], axis=0)

# %%
plt.imshow(vol[15], cmap='gray')
